# %% [markdown]
# #Cargar y explorar datos en Python usando Pandas

# %% [markdown]
# Andrea Catalina Fernández Mena A01197705

# %% [markdown]
# En el siguiente documento se realizará un despliegue de los datos provenientes de Excel en Python utilizando la librería Pandas.

# %%
import pandas as pd  #mando a llamar librería
consumoNutricional_datos = pd.read_excel('DatosSemana1a3.xlsx') #leo los datos que cargué
consumoNutricional_datos.head() #probar que se cargó de manera correcta función head mostrará los primeros 5 datos
#en () podemos poner el número de datos que deseamos reflejar

# %% [markdown]
# Para el siguiente ejemplo mostraremos un total de 60 datos, aunque en total dich excel tiene 214 datos documentados.

# %%
consumoNutricional_datos.head(60) #probar que se cargó de manera correcta función head mostrará los primeros 5 datos
#en () podemos poner el número de datos que deseamos reflejar
# Out:
#    Fecha (dd/mm/aa)  ... Unnamed: 9
# 0        2021-06-28  ...
# 1        2021-06-28  ...
# 2        2021-06-28  ...
# 3        2021-06-28  ...
# 4        2021-06-28  ...
# 5        2021-06-28  ...
# 6        2021-06-28  ...
# 7        2021-06-28  ...
# 8        2021-06-28  ...
# 9        2021-06-28  ...
# 10       2021-06-29  ...
# 11       2021-06-29  ...
# 12       2021-06-29  ...
# 13       2021-06-29  ...
# 14       2021-06-29  ...
# 15       2021-06-29  ...
# 16       2021-06-29  ...
# 17       2021-06-29  ...
# 18       2021-06-29  ...
# 19       2021-06-29  ...
# 20       2021-06-29  ...
# 21       2021-06-29  ...
# 22       2021-06-30  ...
# 23       2021-06-30  ...
# 24       2021-06-30  ...
# 25       2021-06-30  ...
# 26       2021-06-30  ...
# 27       2021-06-30  ...
# 28       2021-06-30  ...
# 29       2021-06-30  ...
# 30       2021-06-30  ...
# 31       2021-06-30  ...
# 32       2021-07-01  ...
# 33       2021-07-01  ...
# 34       2021-07-01  ...
# ...

# %% [markdown]
# Posteriormente para conocer la forma de conocer la forma, expresando el total de filas o columnas de cuestros datos a manera de (filas, columnas).

# %%
consumoNutricional_datos.shape
# Out:
# (218, 10)

# %% [markdown]
# Posteriormente aplicamos el método **columns** con el cuál  podemos ver los nombres de todas las columnas o atributos de nuestros datos:

# %%
consumoNutricional_datos.columns
# Out:
# Index(['Fecha (dd/mm/aa)', 'Momento', 'Nombre alimento', 'Calorías (kcal)',
#        'Carbohidratos (g)', 'Lípidos/grasas (g)', 'Proteína (g)', 'Sodio (mg)',
#        'Fuente', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# Posteriormente para conocer los tipos de datos de nuestro dataframe utilizaremos el método dtypes:
#
# Algunos tipos de datos que podría llegar a mostrar son:
# *   object: cadena de texto
# *   int64 : número entero
# *   float64: número con decimal
# *   datetime64: fecha y hora

# %%
consumoNutricional_datos.dtypes
# Out:
# Fecha (dd/mm/aa)      datetime64[ns]
# Momento                       object
# Nombre alimento               object
# Calorías (kcal)              float64
# Carbohidratos (g)            float64
# Lípidos/grasas (g)           float64
# Proteína (g)                 float64
# Sodio (mg)                   float64
# Fuente                        object
# Unnamed: 9                    object
# dtype: object

# %% [markdown]
# Una vez obtenido esto, se buscará regresar la información completa de los datos del dataframe, lo cual se puede obtener por medio de la función **info()**:

# %%
consumoNutricional_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fecha (dd/mm/aa)    214 non-null    datetime64[ns]
#  1   Momento             214 non-null    object
#  2   Nombre alimento     214 non-null    object
#  3   Calorías (kcal)     214 non-null    float64
#  4   Carbohidratos (g)   214 non-null    float64
#  5   Lípidos/grasas (g)  214 non-null    float64
#  6   Proteína (g)        214 non-null    float64
#  7   Sodio (mg)          214 non-null    float64
#  8   Fuente              214 non-null    object
#  9   Unnamed: 9          217 non-null    object
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 17.2+ KB

# %% [markdown]
# Por último, se utilizaré la función **describe()** para obtener la estadística descriptiva y completar la exploración de nuestros datos:

# %%
consumoNutricional_datos.describe()
# Out:
#        Calorías (kcal)  Carbohidratos (g)  ...  Proteína (g)   Sodio (mg)
# count       214.000000         214.000000  ...    214.000000   214.000000
# mean        144.418224          19.510631  ...      6.348505   206.670561
# std         144.153443          19.369599  ...      8.776986   336.223441
# min           0.000000           0.000000  ...      0.000000     0.000000
# 25%          64.000000           9.665000  ...      1.000000     5.000000
# 50%         105.000000          13.350000  ...      1.845000    80.000000
# 75%         167.000000          26.970000  ...      8.810000   181.000000
# max         875.000000         181.500000  ...     47.000000  1706.000000
#
# [8 rows x 5 columns]
